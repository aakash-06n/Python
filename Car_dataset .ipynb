# %%
import numpy as np
import pandas as pd

# %%
df_cars = pd.read_csv("C:\\Users\\akash\\Downloads\\cars_dataset.csv")

# %%
df_cars.head()
# Out:
#    car_ID  symboling                   carname doornumber      carbody  \
# 0       1          3        alfa-romero giulia        two  convertible
# 1       2          3       alfa-romero stelvio        two  convertible
# 2       3          1  alfa-romero Quadrifoglio        two    hatchback
# 3       4          2               audi 100 ls       four        sedan
# 4       5          2                audi 100ls       four        sedan
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# 0          front       88.6      168.8      64.1       48.8  ...
# 1          front       88.6      168.8      64.1       48.8  ...
# 2          front       94.5      171.2      65.5       52.4  ...
# 3          front       99.8      176.6      66.2       54.3  ...
# 4          front       99.4      176.6      66.4       54.3  ...
#
#    cylindernumber enginesize  boreratio  stroke  compressionratio  horsepower  \
# ...

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            147 non-null    int64
#  1   symboling         147 non-null    int64
#  2   carname           147 non-null    object
#  3   doornumber        147 non-null    object
#  4   carbody           147 non-null    object
#  5   enginelocation    147 non-null    object
#  6   wheelbase         147 non-null    float64
#  7   carlength         147 non-null    float64
#  8   carwidth          147 non-null    float64
#  9   carheight         147 non-null    float64
#  10  curbweight        147 non-null    int64
#  11  cylindernumber    147 non-null    object
#  12  enginesize        147 non-null    int64
#  13  boreratio         147 non-null    float64
#  14  stroke            147 non-null    float64
#  15  compressionratio  147 non-null    float64
# ...

# %%
df_cars.shape
# Out:
# (147, 21)

# %%
df_cars.size
# Out:
# 3087

# %%
df_cars.ndim
# Out:
# 2

# %%
df_cars.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  147.000000  147.000000  147.000000  147.000000  147.000000  147.000000
# mean    96.530612    0.931973   98.087755  172.873469   65.710884   53.664626
# std     60.034386    1.225639    6.108257   12.835948    2.185448    2.564879
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     44.500000    0.000000   94.500000  165.300000   63.900000   51.600000
# 50%     94.000000    1.000000   96.500000  171.700000   65.400000   53.700000
# 75%    146.500000    2.000000  100.400000  180.200000   66.500000   55.650000
# max    204.000000    3.000000  120.900000  208.100000   72.000000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   147.000000  147.000000  147.000000  147.000000        147.000000
# mean   2527.469388  126.523810    3.303469    3.266599         10.255238
# ...

# %% [markdown]
# # How to access carname column

# %%
df_cars.carname
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 142                 volvo 244dl
# 143                   volvo 245
# 144                 volvo 264gl
# 145                volvo diesel
# 146                   volvo 246
# Name: carname, Length: 147, dtype: object

# %%
df_cars['carname']
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 142                 volvo 244dl
# 143                   volvo 245
# 144                 volvo 264gl
# 145                volvo diesel
# 146                   volvo 246
# Name: carname, Length: 147, dtype: object

# %%
df_cars.get('carname')
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 142                 volvo 244dl
# 143                   volvo 245
# 144                 volvo 264gl
# 145                volvo diesel
# 146                   volvo 246
# Name: carname, Length: 147, dtype: object

# %% [markdown]
# # How to access multiple columns

# %%
df_cars[['carname','price']]
# Out:
#                       carname    price
# 0          alfa-romero giulia  13495.0
# 1         alfa-romero stelvio  16500.0
# 2    alfa-romero Quadrifoglio  16500.0
# 3                 audi 100 ls  13950.0
# 4                  audi 100ls  17450.0
# ..                        ...      ...
# 142               volvo 244dl  15985.0
# 143                 volvo 245  16515.0
# 144               volvo 264gl  18420.0
# 145              volvo diesel  18950.0
# 146                 volvo 246  22470.0
#
# [147 rows x 2 columns]
